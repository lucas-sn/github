# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv('tabela.csv', sep = ',', index_col = 0)

# %%
data['peso(toneladas)'] = data['peso']
data['distância(Km)'] = data['distancia']
data.head('')
# Out:
#    distancia   peso cod_origem cod_destino  peso(toneladas)  distância(Km)
# 0      160.0  0.050         SP          SP            0.050          160.0
# 1       11.0  0.050         SP          SP            0.050           11.0
# 2     2384.0  0.054         SP          AL            0.054         2384.0
# 3     2384.0  0.054         SP          AL            0.054         2384.0
# 4     2384.0  0.054         SP          AL            0.054         2384.0

# %%
data = pd.read_csv('tables.csv', sep = ',')

ax = data[data['cod_destino'] == 'SP'].plot(kind = 'scatter', x = 'peso(toneladas)', y = 'distância(Km)', color = 'blue', label = 'destino SP', figsize = (12,9))
data[data['cod_destino'] == 'MG'].plot(kind = 'scatter', x = 'peso(toneladas)', y = 'distância(Km)', color = 'red', label = 'destino MG' , ax = ax)

# %%
plot = data.pivot_table(values = data['peso'], index = data['distancia'], columns = data['cod_destino'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-41ef16ca7c8e> in <module>()
# ----> 1 plot = data.pivot_table(values = data['peso'], index = data['distancia'], columns = data['cod_destino'])
#
# /usr/local/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5301                            aggfunc=aggfunc, fill_value=fill_value,
#    5302                            margins=margins, dropna=dropna,
# -> 5303                            margins_name=margins_name)
#    5304
#    5305     def stack(self, level=-1, dropna=True):
#
# /usr/local/anaconda/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      59         for i in values:
# ...

# %%
plot.scatter(data)
# Out:
#   File "<ipython-input-21-2d7827593a34>", line 3
#     >>> ax1 = df.plot.scatter(x='length',
#      ^
# SyntaxError: invalid syntax
